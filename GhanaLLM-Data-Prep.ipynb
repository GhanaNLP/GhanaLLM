# %% [markdown]
# # TRANSLATE USING GTRANSLATE

# %%
pip install googletrans
# Out:
# Collecting googletrans
#   Downloading googletrans-4.0.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: httpx>=0.27.2 in /usr/local/lib/python3.12/dist-packages (from httpx[http2]>=0.27.2->googletrans) (0.28.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27.2->httpx[http2]>=0.27.2->googletrans) (4.11.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27.2->httpx[http2]>=0.27.2->googletrans) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27.2->httpx[http2]>=0.27.2->googletrans) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27.2->httpx[http2]>=0.27.2->googletrans) (3.10)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.27.2->httpx[http2]>=0.27.2->googletrans) (0.16.0)
# Requirement already satisfied: h2<5,>=3 in /usr/local/lib/python3.12/dist-packages (from httpx[http2]>=0.27.2->googletrans) (4.3.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in /usr/local/lib/python3.12/dist-packages (from h2<5,>=3->httpx[http2]>=0.27.2->googletrans) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /usr/local/lib/python3.12/dist-packages (from h2<5,>=3->httpx[http2]>=0.27.2->googletrans) (4.1.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx>=0.27.2->httpx[http2]>=0.27.2->googletrans) (1.3.1)
# Requirement already satisfied: typing_extensions>=4.5 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx>=0.27.2->httpx[http2]>=0.27.2->googletrans) (4.15.0)
# Downloading googletrans-4.0.2-py3-none-any.whl (18 kB)
# Installing collected packages: googletrans
# Successfully installed googletrans-4.0.2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#!/usr/bin/env python3
"""
Bulk-translate a CSV column that contains Python-list-of-dicts conversations
into Twi (Akan) – fast, resumable, parallel using googletrans async API.
"""
import asyncio
import ast
import json
import sys
import time
from pathlib import Path
from typing import Any, Dict, List, Tuple

import pandas as pd
from googletrans import Translator

# ------------------------------------------------------------------ CONFIG
MAX_CONCURRENT = 20           # concurrent translators (be gentle with Google)
BATCH_SIZE     = 20          # texts per batch
CHUNK_SIZE     = 500         # rows between disk writes
DEST_LANG      = "gaa"        # Twi (Akan)
RETRY_DELAY    = 2           # seconds between retries
MAX_RETRIES    = 3           # max retries per batch
PROGRESS_FILE  = Path("/content/drive/MyDrive/Collab/Boafo/translation_progress.json")
INPUT_FILE     = Path("/content/drive/MyDrive/Collab/Boafo/code-dataset-output_eng-placeholders.csv")
OUTPUT_FILE    = Path("/content/drive/MyDrive/Collab/Boafo/code-dataset-output_twi.csv")

# ------------------------------------------------------------------ UTILS
def load_progress() -> Dict[str, Any]:
    if PROGRESS_FILE.exists():
        try:
            return json.loads(PROGRESS_FILE.read_text(encoding="utf8"))
        except Exception as e:
            print(f"⚠️  Corrupt progress file ({e}) – starting fresh.")
    return {"processed": [], "last_idx": -1, "errors": []}

def save_progress(progress: Dict[str, Any]) -> None:
    PROGRESS_FILE.write_text(json.dumps(progress, indent=2, ensure_ascii=False), encoding="utf8")

# ------------------------------------------------------------------ CONVERSATION HELPERS
def extract_texts(conv: List[Dict[str, Any]]) -> Tuple[List[str], List[int]]:
    texts, idx_map = [], []
    for i, msg in enumerate(conv):
        if isinstance(msg, dict) and msg.get("value"):
            text = str(msg["value"]).strip()
            if text:  # only add non-empty texts
                texts.append(text)
                idx_map.append(i)
    return texts, idx_map

def rebuild(conv: List[Dict[str, Any]], idx_map: List[int], translations: List[str]) -> List[Dict[str, Any]]:
    out = [dict(m) for m in conv]
    for j, idx in enumerate(idx_map):
        if j < len(translations):
            out[idx]["value"] = translations[j]
    return out

# ------------------------------------------------------------------ TRANSLATION WITH RETRY
async def translate_texts_with_retry(translator: Translator, texts: List[str], max_retries: int = MAX_RETRIES) -> List[str]:
    """Translate texts with retry logic using async googletrans"""

    for attempt in range(max_retries + 1):
        try:
            if not texts:
                return []

            # Translate in smaller batches to avoid rate limits
            results = []
            for i in range(0, len(texts), BATCH_SIZE):
                batch = texts[i:i + BATCH_SIZE]

                # Use the async translate method
                translated = await translator.translate(batch, dest=DEST_LANG)

                # Handle both single translation and list of translations
                if isinstance(translated, list):
                    results.extend([t.text for t in translated])
                else:
                    results.append(translated.text)

                # Small delay between batches to be nice to Google
                if i + BATCH_SIZE < len(texts):
                    await asyncio.sleep(0.1)

            return results

        except Exception as e:
            if attempt < max_retries:
                print(f"  ⚠️  Translation attempt {attempt + 1} failed: {e}. Retrying in {RETRY_DELAY}s...")
                await asyncio.sleep(RETRY_DELAY * (attempt + 1))  # exponential backoff
            else:
                print(f"  ❌  Translation failed after {max_retries + 1} attempts: {e}")
                return texts  # return original texts if all retries fail

# ------------------------------------------------------------------ SINGLE ROW WORKER
async def translate_one_row(idx: int, row: pd.Series, translator: Translator) -> Tuple[int, str, str | None]:
    """Return (index, new_conversations_string, error_or_None)"""
    try:
        conv = ast.literal_eval(str(row["conversations"]))
        texts, idx_map = extract_texts(conv)

        if texts:
            translations = await translate_texts_with_retry(translator, texts)
            new_conv = rebuild(conv, idx_map, translations)
        else:
            new_conv = conv

        return idx, str(new_conv), None

    except Exception as exc:
        error_msg = f"Row {idx}: {str(exc)}"
        print(f"  ❌  {error_msg}")
        return idx, str(row["conversations"]), error_msg

# ------------------------------------------------------------------ CHUNK PROCESSOR
async def process_chunk(
    chunk_rows: List[int], df: pd.DataFrame, translator: Translator, progress: Dict[str, Any]
) -> None:
    """Process a chunk of rows using semaphore for concurrency control"""
    import asyncio

    # Semaphore to limit concurrent translations
    semaphore = asyncio.Semaphore(MAX_CONCURRENT)

    async def _translate_with_semaphore(idx: int):
        async with semaphore:
            return await translate_one_row(idx, df.iloc[idx], translator)

    # Process all rows in the chunk concurrently
    results = await asyncio.gather(*[_translate_with_semaphore(idx) for idx in chunk_rows])

    # Update in-memory dataframe
    error_count = 0
    for idx, new_conv, err in results:
        df.at[idx, "conversations_twi"] = new_conv
        progress["processed"].append(idx)
        if err:
            progress["errors"].append({"row": idx, "error": err})
            error_count += 1

    progress["last_idx"] = max(progress["last_idx"], max(chunk_rows))

    # Single disk write per chunk
    df.to_csv(OUTPUT_FILE, index=False)
    save_progress(progress)

    success_count = len(chunk_rows) - error_count
    print(f"  ✅  Processed chunk: {success_count} success, {error_count} errors (total done: {len(progress['processed'])})")

# ------------------------------------------------------------------ MAIN
async def main_async() -> None:
    import asyncio

    if "--reset" in sys.argv:
        if PROGRESS_FILE.exists():
            PROGRESS_FILE.unlink()
        print("🗑️  Progress reset – starting fresh.")

    progress = load_progress()

    print(f"📖  Loading CSV from: {INPUT_FILE}")
    df = pd.read_csv(INPUT_FILE)

    if "conversations_twi" not in df.columns:
        df["conversations_twi"] = None

    all_rows = set(range(len(df)))
    done_rows = set(progress["processed"])
    todo_rows = sorted(all_rows - done_rows)

    if not todo_rows:
        print("🎉  All rows already translated!")
        return

    print(f"📊  Rows total: {len(df)}  |  Done: {len(done_rows)}  |  Todo: {len(todo_rows)}")
    print(f"🔧  Config: {MAX_CONCURRENT} concurrent, {CHUNK_SIZE} chunk size, '{DEST_LANG}' target")
    print(f"💾  Output: {OUTPUT_FILE}")

    start_time = time.time()

    # Create translator with async context manager
    async with Translator() as translator:
        for i in range(0, len(todo_rows), CHUNK_SIZE):
            chunk = todo_rows[i : i + CHUNK_SIZE]
            chunk_num = i // CHUNK_SIZE + 1
            total_chunks = (len(todo_rows) + CHUNK_SIZE - 1) // CHUNK_SIZE

            print(f"\n🔄  Processing chunk {chunk_num}/{total_chunks} (rows {chunk[0]}-{chunk[-1]})...")
            await process_chunk(chunk, df, translator, progress)

            # Progress estimate
            elapsed = time.time() - start_time
            completed = len(progress["processed"]) - len(done_rows)  # newly completed
            if completed > 0:
                rate = completed / elapsed
                remaining = len(todo_rows) - completed
                eta = remaining / rate if rate > 0 else 0
                print(f"  📈  Rate: {rate:.1f} rows/sec, ETA: {eta/60:.1f} minutes")

    errors = progress.get("errors", [])
    print(f"\n✅  Translation complete!")
    print(f"📊  Total processed: {len(progress['processed'])}")
    print(f"❌  Errors: {len(errors)}")
    print(f"💾  Output saved to: {OUTPUT_FILE}")

    if errors:
        print(f"\n⚠️  Errors occurred in {len(errors)} rows:")
        for err in errors[-5:]:  # show last 5 errors
            print(f"    Row {err['row']}: {err['error']}")

# ------------------------------------------------------------------ JUPYTER-COMPATIBLE MAIN
def main():
    """Main function that works in both Jupyter and standalone Python"""
    import asyncio
    import nest_asyncio

    try:
        # Try to get the current event loop
        loop = asyncio.get_running_loop()
        # If we get here, we're in Jupyter/IPython with a running event loop
        print("🔄  Detected running event loop (Jupyter/IPython), using nest_asyncio...")

        # Install nest_asyncio to allow nested event loops
        try:
            nest_asyncio.apply()
            return loop.run_until_complete(main_async())
        except ImportError:
            print("📦  Installing nest_asyncio...")
            import subprocess
            subprocess.check_call([sys.executable, "-m", "pip", "install", "nest_asyncio"])
            import nest_asyncio
            nest_asyncio.apply()
            return loop.run_until_complete(main_async())

    except RuntimeError:
        # No event loop running, we can use asyncio.run()
        return asyncio.run(main_async())

# ------------------------------------------------------------------ ENTRY
if __name__ == "__main__":
    try:
        main()
    except KeyboardInterrupt:
        print("\n⏹️  Interrupted by user – progress saved.")
    except Exception as e:
        print(f"❌  Fatal error: {e}")
        import traceback
        traceback.print_exc()
else:
    # When imported/run in Jupyter, execute main directly
    try:
        main()
    except KeyboardInterrupt:
        print("\n⏹️  Interrupted by user – progress saved.")
    except Exception as e:
        print(f"❌  Fatal error: {e}")
        import traceback
        traceback.print_exc()
# Out:
# 🔄  Detected running event loop (Jupyter/IPython), using nest_asyncio...
# 📖  Loading CSV from: /content/drive/MyDrive/Collab/Boafo/code-dataset-output_eng-placeholders.csv
# 📊  Rows total: 176999  |  Done: 0  |  Todo: 176999
# 🔧  Config: 20 concurrent, 500 chunk size, 'gaa' target
# 💾  Output: /content/drive/MyDrive/Collab/Boafo/code-dataset-output_twi.csv
#
# 🔄  Processing chunk 1/354 (rows 0-499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 500)
#   📈  Rate: 20.7 rows/sec, ETA: 142.0 minutes
#
# 🔄  Processing chunk 2/354 (rows 500-999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 1000)
#   📈  Rate: 19.6 rows/sec, ETA: 149.4 minutes
#
# 🔄  Processing chunk 3/354 (rows 1000-1499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 1500)
#   📈  Rate: 20.4 rows/sec, ETA: 143.4 minutes
#
# 🔄  Processing chunk 4/354 (rows 1500-1999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 2000)
#   📈  Rate: 20.2 rows/sec, ETA: 144.2 minutes
#
# 🔄  Processing chunk 5/354 (rows 2000-2499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 2500)
#   📈  Rate: 20.3 rows/sec, ETA: 143.6 minutes
#
# 🔄  Processing chunk 6/354 (rows 2500-2999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 3000)
#   📈  Rate: 20.1 rows/sec, ETA: 144.1 minutes
#
# 🔄  Processing chunk 7/354 (rows 3000-3499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 3500)
#   📈  Rate: 20.0 rows/sec, ETA: 144.4 minutes
#
# 🔄  Processing chunk 8/354 (rows 3500-3999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 4000)
#   📈  Rate: 20.0 rows/sec, ETA: 144.4 minutes
#
# 🔄  Processing chunk 9/354 (rows 4000-4499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 4500)
#   📈  Rate: 20.0 rows/sec, ETA: 143.9 minutes
#
# 🔄  Processing chunk 10/354 (rows 4500-4999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 5000)
#   📈  Rate: 19.8 rows/sec, ETA: 144.4 minutes
#
# 🔄  Processing chunk 11/354 (rows 5000-5499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 5500)
#   📈  Rate: 19.8 rows/sec, ETA: 144.4 minutes
#
# 🔄  Processing chunk 12/354 (rows 5500-5999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 6000)
#   📈  Rate: 19.8 rows/sec, ETA: 144.0 minutes
#
# 🔄  Processing chunk 13/354 (rows 6000-6499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 6500)
#   📈  Rate: 19.6 rows/sec, ETA: 145.3 minutes
#
# 🔄  Processing chunk 14/354 (rows 6500-6999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 7000)
#   📈  Rate: 19.6 rows/sec, ETA: 144.6 minutes
#
# 🔄  Processing chunk 15/354 (rows 7000-7499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 7500)
#   📈  Rate: 19.5 rows/sec, ETA: 144.8 minutes
#
# 🔄  Processing chunk 16/354 (rows 7500-7999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 8000)
#   📈  Rate: 19.5 rows/sec, ETA: 144.1 minutes
#
# 🔄  Processing chunk 17/354 (rows 8000-8499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 8500)
#   📈  Rate: 19.6 rows/sec, ETA: 143.0 minutes
#
# 🔄  Processing chunk 18/354 (rows 8500-8999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 9000)
#   📈  Rate: 19.7 rows/sec, ETA: 142.2 minutes
#
# 🔄  Processing chunk 19/354 (rows 9000-9499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 9500)
#   📈  Rate: 19.7 rows/sec, ETA: 141.7 minutes
#
# 🔄  Processing chunk 20/354 (rows 9500-9999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 10000)
#   📈  Rate: 19.7 rows/sec, ETA: 141.2 minutes
#
# 🔄  Processing chunk 21/354 (rows 10000-10499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 10500)
#   📈  Rate: 19.7 rows/sec, ETA: 140.9 minutes
#
# 🔄  Processing chunk 22/354 (rows 10500-10999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 11000)
#   📈  Rate: 19.6 rows/sec, ETA: 140.8 minutes
#
# 🔄  Processing chunk 23/354 (rows 11000-11499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 11500)
#   📈  Rate: 19.6 rows/sec, ETA: 140.6 minutes
#
# 🔄  Processing chunk 24/354 (rows 11500-11999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 12000)
#   📈  Rate: 19.6 rows/sec, ETA: 140.3 minutes
#
# 🔄  Processing chunk 25/354 (rows 12000-12499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 12500)
#   📈  Rate: 19.6 rows/sec, ETA: 139.8 minutes
#
# 🔄  Processing chunk 26/354 (rows 12500-12999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 13000)
#   📈  Rate: 19.5 rows/sec, ETA: 140.3 minutes
#
# 🔄  Processing chunk 27/354 (rows 13000-13499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 13500)
#   📈  Rate: 19.5 rows/sec, ETA: 139.7 minutes
#
# 🔄  Processing chunk 28/354 (rows 13500-13999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 14000)
#   📈  Rate: 19.5 rows/sec, ETA: 139.3 minutes
#
# 🔄  Processing chunk 29/354 (rows 14000-14499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 14500)
#   📈  Rate: 19.5 rows/sec, ETA: 138.9 minutes
#
# 🔄  Processing chunk 30/354 (rows 14500-14999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 15000)
#   📈  Rate: 19.5 rows/sec, ETA: 138.4 minutes
#
# 🔄  Processing chunk 31/354 (rows 15000-15499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 15500)
#   📈  Rate: 19.4 rows/sec, ETA: 138.5 minutes
#
# 🔄  Processing chunk 32/354 (rows 15500-15999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 16000)
#   📈  Rate: 19.4 rows/sec, ETA: 138.0 minutes
#
# 🔄  Processing chunk 33/354 (rows 16000-16499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 16500)
#   📈  Rate: 19.4 rows/sec, ETA: 137.7 minutes
#
# 🔄  Processing chunk 34/354 (rows 16500-16999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 17000)
#   📈  Rate: 19.4 rows/sec, ETA: 137.3 minutes
#
# 🔄  Processing chunk 35/354 (rows 17000-17499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 17500)
#   📈  Rate: 19.4 rows/sec, ETA: 136.8 minutes
#
# 🔄  Processing chunk 36/354 (rows 17500-17999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 18000)
#   📈  Rate: 19.5 rows/sec, ETA: 136.1 minutes
#
# 🔄  Processing chunk 37/354 (rows 18000-18499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 18500)
#   📈  Rate: 19.5 rows/sec, ETA: 135.8 minutes
#
# 🔄  Processing chunk 38/354 (rows 18500-18999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 19000)
#   📈  Rate: 19.4 rows/sec, ETA: 135.5 minutes
#
# 🔄  Processing chunk 39/354 (rows 19000-19499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 19500)
#   📈  Rate: 19.4 rows/sec, ETA: 135.1 minutes
#
# 🔄  Processing chunk 40/354 (rows 19500-19999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 20000)
#   📈  Rate: 19.4 rows/sec, ETA: 134.7 minutes
#
# 🔄  Processing chunk 41/354 (rows 20000-20499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 20500)
#   📈  Rate: 19.4 rows/sec, ETA: 134.6 minutes
#
# 🔄  Processing chunk 42/354 (rows 20500-20999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 21000)
#   📈  Rate: 19.4 rows/sec, ETA: 134.0 minutes
#
# 🔄  Processing chunk 43/354 (rows 21000-21499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 21500)
#   📈  Rate: 19.4 rows/sec, ETA: 133.8 minutes
#
# 🔄  Processing chunk 44/354 (rows 21500-21999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 22000)
#   📈  Rate: 19.4 rows/sec, ETA: 133.3 minutes
#
# 🔄  Processing chunk 45/354 (rows 22000-22499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 22500)
#   📈  Rate: 19.4 rows/sec, ETA: 132.9 minutes
#
# 🔄  Processing chunk 46/354 (rows 22500-22999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 23000)
#   📈  Rate: 19.4 rows/sec, ETA: 132.6 minutes
#
# 🔄  Processing chunk 47/354 (rows 23000-23499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 23500)
#   📈  Rate: 19.4 rows/sec, ETA: 132.2 minutes
#
# 🔄  Processing chunk 48/354 (rows 23500-23999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 24000)
#   📈  Rate: 19.3 rows/sec, ETA: 131.9 minutes
#
# 🔄  Processing chunk 49/354 (rows 24000-24499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 24500)
#   📈  Rate: 19.3 rows/sec, ETA: 131.7 minutes
#
# 🔄  Processing chunk 50/354 (rows 24500-24999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 25000)
#   📈  Rate: 19.3 rows/sec, ETA: 131.2 minutes
#
# 🔄  Processing chunk 51/354 (rows 25000-25499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 25500)
#   📈  Rate: 19.3 rows/sec, ETA: 131.1 minutes
#
# 🔄  Processing chunk 52/354 (rows 25500-25999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 26000)
#   📈  Rate: 19.2 rows/sec, ETA: 130.9 minutes
#
# 🔄  Processing chunk 53/354 (rows 26000-26499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 26500)
#   📈  Rate: 19.2 rows/sec, ETA: 130.8 minutes
#
# 🔄  Processing chunk 54/354 (rows 26500-26999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 27000)
#   📈  Rate: 19.2 rows/sec, ETA: 130.4 minutes
#
# 🔄  Processing chunk 55/354 (rows 27000-27499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 27500)
#   📈  Rate: 19.1 rows/sec, ETA: 130.2 minutes
#
# 🔄  Processing chunk 56/354 (rows 27500-27999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 28000)
#   📈  Rate: 19.2 rows/sec, ETA: 129.6 minutes
#
# 🔄  Processing chunk 57/354 (rows 28000-28499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 28500)
#   📈  Rate: 19.1 rows/sec, ETA: 129.3 minutes
#
# 🔄  Processing chunk 58/354 (rows 28500-28999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 29000)
#   📈  Rate: 19.1 rows/sec, ETA: 129.0 minutes
#
# 🔄  Processing chunk 59/354 (rows 29000-29499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 29500)
#   📈  Rate: 19.1 rows/sec, ETA: 128.7 minutes
#
# 🔄  Processing chunk 60/354 (rows 29500-29999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 30000)
#   📈  Rate: 19.1 rows/sec, ETA: 128.3 minutes
#
# 🔄  Processing chunk 61/354 (rows 30000-30499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 30500)
#   📈  Rate: 19.1 rows/sec, ETA: 127.8 minutes
#
# 🔄  Processing chunk 62/354 (rows 30500-30999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 31000)
#   📈  Rate: 19.1 rows/sec, ETA: 127.5 minutes
#
# 🔄  Processing chunk 63/354 (rows 31000-31499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 31500)
#   📈  Rate: 19.1 rows/sec, ETA: 127.1 minutes
#
# 🔄  Processing chunk 64/354 (rows 31500-31999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 32000)
#   📈  Rate: 19.1 rows/sec, ETA: 126.6 minutes
#
# 🔄  Processing chunk 65/354 (rows 32000-32499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 32500)
#   📈  Rate: 19.1 rows/sec, ETA: 126.3 minutes
#
# 🔄  Processing chunk 66/354 (rows 32500-32999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 33000)
#   📈  Rate: 19.1 rows/sec, ETA: 125.9 minutes
#
# 🔄  Processing chunk 67/354 (rows 33000-33499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 33500)
#   📈  Rate: 19.1 rows/sec, ETA: 125.4 minutes
#
# 🔄  Processing chunk 68/354 (rows 33500-33999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 34000)
#   📈  Rate: 19.1 rows/sec, ETA: 124.9 minutes
#
# 🔄  Processing chunk 69/354 (rows 34000-34499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 34500)
#   📈  Rate: 19.1 rows/sec, ETA: 124.6 minutes
#
# 🔄  Processing chunk 70/354 (rows 34500-34999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 35000)
#   📈  Rate: 19.0 rows/sec, ETA: 124.3 minutes
#
# 🔄  Processing chunk 71/354 (rows 35000-35499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 35500)
#   📈  Rate: 19.0 rows/sec, ETA: 123.9 minutes
#
# 🔄  Processing chunk 72/354 (rows 35500-35999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 36000)
#   📈  Rate: 19.0 rows/sec, ETA: 123.7 minutes
#
# 🔄  Processing chunk 73/354 (rows 36000-36499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 36500)
#   📈  Rate: 19.0 rows/sec, ETA: 123.3 minutes
#
# 🔄  Processing chunk 74/354 (rows 36500-36999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 37000)
#   📈  Rate: 19.0 rows/sec, ETA: 123.0 minutes
#
# 🔄  Processing chunk 75/354 (rows 37000-37499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 37500)
#   📈  Rate: 18.9 rows/sec, ETA: 122.8 minutes
#
# 🔄  Processing chunk 76/354 (rows 37500-37999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 38000)
#   📈  Rate: 18.9 rows/sec, ETA: 122.4 minutes
#
# 🔄  Processing chunk 77/354 (rows 38000-38499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 38500)
#   📈  Rate: 18.9 rows/sec, ETA: 122.0 minutes
#
# 🔄  Processing chunk 78/354 (rows 38500-38999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 39000)
#   📈  Rate: 18.9 rows/sec, ETA: 121.6 minutes
#
# 🔄  Processing chunk 79/354 (rows 39000-39499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 39500)
#   📈  Rate: 18.9 rows/sec, ETA: 121.2 minutes
#
# 🔄  Processing chunk 80/354 (rows 39500-39999)...
#   ⚠️  Translation attempt 1 failed: URL component 'query' too long. Retrying in 2s...
#   ⚠️  Translation attempt 2 failed: URL component 'query' too long. Retrying in 2s...
#   ⚠️  Translation attempt 3 failed: URL component 'query' too long. Retrying in 2s...
#   ❌  Translation failed after 4 attempts: URL component 'query' too long
#   ✅  Processed chunk: 500 success, 0 errors (total done: 40000)
#   📈  Rate: 18.9 rows/sec, ETA: 120.9 minutes
#
# 🔄  Processing chunk 81/354 (rows 40000-40499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 40500)
#   📈  Rate: 18.9 rows/sec, ETA: 120.6 minutes
#
# 🔄  Processing chunk 82/354 (rows 40500-40999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 41000)
#   📈  Rate: 18.8 rows/sec, ETA: 120.3 minutes
#
# 🔄  Processing chunk 83/354 (rows 41000-41499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 41500)
#   📈  Rate: 18.8 rows/sec, ETA: 120.0 minutes
#
# 🔄  Processing chunk 84/354 (rows 41500-41999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 42000)
#   📈  Rate: 18.8 rows/sec, ETA: 119.6 minutes
#
# 🔄  Processing chunk 85/354 (rows 42000-42499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 42500)
#   📈  Rate: 18.8 rows/sec, ETA: 119.3 minutes
#
# 🔄  Processing chunk 86/354 (rows 42500-42999)...
#   ⚠️  Translation attempt 1 failed: 'utf-8' codec can't encode characters in position 270-271: surrogates not allowed. Retrying in 2s...
#   ⚠️  Translation attempt 2 failed: 'utf-8' codec can't encode characters in position 270-271: surrogates not allowed. Retrying in 2s...
#   ⚠️  Translation attempt 3 failed: 'utf-8' codec can't encode characters in position 270-271: surrogates not allowed. Retrying in 2s...
#   ❌  Translation failed after 4 attempts: 'utf-8' codec can't encode characters in position 270-271: surrogates not allowed
#   ✅  Processed chunk: 500 success, 0 errors (total done: 43000)
#   📈  Rate: 18.7 rows/sec, ETA: 119.4 minutes
#
# 🔄  Processing chunk 87/354 (rows 43000-43499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 43500)
#   📈  Rate: 18.7 rows/sec, ETA: 119.1 minutes
#
# 🔄  Processing chunk 88/354 (rows 43500-43999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 44000)
#   📈  Rate: 18.7 rows/sec, ETA: 118.7 minutes
#
# 🔄  Processing chunk 89/354 (rows 44000-44499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 44500)
#   📈  Rate: 18.7 rows/sec, ETA: 118.3 minutes
#
# 🔄  Processing chunk 90/354 (rows 44500-44999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 45000)
#   📈  Rate: 18.6 rows/sec, ETA: 118.0 minutes
#
# 🔄  Processing chunk 91/354 (rows 45000-45499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 45500)
#   📈  Rate: 18.6 rows/sec, ETA: 117.5 minutes
#
# 🔄  Processing chunk 92/354 (rows 45500-45999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 46000)
#   📈  Rate: 18.6 rows/sec, ETA: 117.2 minutes
#
# 🔄  Processing chunk 93/354 (rows 46000-46499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 46500)
#   📈  Rate: 18.6 rows/sec, ETA: 116.8 minutes
#
# 🔄  Processing chunk 94/354 (rows 46500-46999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 47000)
#   📈  Rate: 18.6 rows/sec, ETA: 116.4 minutes
#
# 🔄  Processing chunk 95/354 (rows 47000-47499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 47500)
#   📈  Rate: 18.6 rows/sec, ETA: 116.0 minutes
#
# 🔄  Processing chunk 96/354 (rows 47500-47999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 48000)
#   📈  Rate: 18.6 rows/sec, ETA: 115.7 minutes
#
# 🔄  Processing chunk 97/354 (rows 48000-48499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 48500)
#   📈  Rate: 18.6 rows/sec, ETA: 115.3 minutes
#
# 🔄  Processing chunk 98/354 (rows 48500-48999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 49000)
#   📈  Rate: 18.6 rows/sec, ETA: 115.0 minutes
#
# 🔄  Processing chunk 99/354 (rows 49000-49499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 49500)
#   📈  Rate: 18.5 rows/sec, ETA: 114.7 minutes
#
# 🔄  Processing chunk 100/354 (rows 49500-49999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 50000)
#   📈  Rate: 18.5 rows/sec, ETA: 114.3 minutes
#
# 🔄  Processing chunk 101/354 (rows 50000-50499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 50500)
#   📈  Rate: 18.5 rows/sec, ETA: 113.9 minutes
#
# 🔄  Processing chunk 102/354 (rows 50500-50999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 51000)
#   📈  Rate: 18.5 rows/sec, ETA: 113.6 minutes
#
# 🔄  Processing chunk 103/354 (rows 51000-51499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 51500)
#   📈  Rate: 18.5 rows/sec, ETA: 113.2 minutes
#
# 🔄  Processing chunk 104/354 (rows 51500-51999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 52000)
#   📈  Rate: 18.4 rows/sec, ETA: 112.9 minutes
#
# 🔄  Processing chunk 105/354 (rows 52000-52499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 52500)
#   📈  Rate: 18.4 rows/sec, ETA: 112.6 minutes
#
# 🔄  Processing chunk 106/354 (rows 52500-52999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 53000)
#   📈  Rate: 18.4 rows/sec, ETA: 112.2 minutes
#
# 🔄  Processing chunk 107/354 (rows 53000-53499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 53500)
#   📈  Rate: 18.4 rows/sec, ETA: 111.8 minutes
#
# 🔄  Processing chunk 108/354 (rows 53500-53999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 54000)
#   📈  Rate: 18.4 rows/sec, ETA: 111.4 minutes
#
# 🔄  Processing chunk 109/354 (rows 54000-54499)...
#   ⚠️  Translation attempt 1 failed: 'utf-8' codec can't encode characters in position 550-551: surrogates not allowed. Retrying in 2s...
#   ⚠️  Translation attempt 2 failed: 'utf-8' codec can't encode characters in position 550-551: surrogates not allowed. Retrying in 2s...
#   ⚠️  Translation attempt 3 failed: 'utf-8' codec can't encode characters in position 550-551: surrogates not allowed. Retrying in 2s...
#   ❌  Translation failed after 4 attempts: 'utf-8' codec can't encode characters in position 550-551: surrogates not allowed
#   ✅  Processed chunk: 500 success, 0 errors (total done: 54500)
#   📈  Rate: 18.3 rows/sec, ETA: 111.5 minutes
#
# 🔄  Processing chunk 110/354 (rows 54500-54999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 55000)
#   📈  Rate: 18.3 rows/sec, ETA: 111.0 minutes
#
# 🔄  Processing chunk 111/354 (rows 55000-55499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 55500)
#   📈  Rate: 18.3 rows/sec, ETA: 110.6 minutes
#
# 🔄  Processing chunk 112/354 (rows 55500-55999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 56000)
#   📈  Rate: 18.3 rows/sec, ETA: 110.3 minutes
#
# 🔄  Processing chunk 113/354 (rows 56000-56499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 56500)
#   📈  Rate: 18.3 rows/sec, ETA: 109.8 minutes
#
# 🔄  Processing chunk 114/354 (rows 56500-56999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 57000)
#   📈  Rate: 18.3 rows/sec, ETA: 109.4 minutes
#
# 🔄  Processing chunk 115/354 (rows 57000-57499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 57500)
#   📈  Rate: 18.3 rows/sec, ETA: 109.0 minutes
#
# 🔄  Processing chunk 116/354 (rows 57500-57999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 58000)
#   📈  Rate: 18.3 rows/sec, ETA: 108.6 minutes
#
# 🔄  Processing chunk 117/354 (rows 58000-58499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 58500)
#   📈  Rate: 18.2 rows/sec, ETA: 108.2 minutes
#
# 🔄  Processing chunk 118/354 (rows 58500-58999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 59000)
#   📈  Rate: 18.2 rows/sec, ETA: 107.8 minutes
#
# 🔄  Processing chunk 119/354 (rows 59000-59499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 59500)
#   📈  Rate: 18.2 rows/sec, ETA: 107.4 minutes
#
# 🔄  Processing chunk 120/354 (rows 59500-59999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 60000)
#   📈  Rate: 18.2 rows/sec, ETA: 106.9 minutes
#
# 🔄  Processing chunk 121/354 (rows 60000-60499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 60500)
#   📈  Rate: 18.2 rows/sec, ETA: 106.4 minutes
#
# 🔄  Processing chunk 122/354 (rows 60500-60999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 61000)
#   📈  Rate: 18.2 rows/sec, ETA: 106.0 minutes
#
# 🔄  Processing chunk 123/354 (rows 61000-61499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 61500)
#   📈  Rate: 18.2 rows/sec, ETA: 105.6 minutes
#
# 🔄  Processing chunk 124/354 (rows 61500-61999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 62000)
#   📈  Rate: 18.2 rows/sec, ETA: 105.3 minutes
#
# 🔄  Processing chunk 125/354 (rows 62000-62499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 62500)
#   📈  Rate: 18.2 rows/sec, ETA: 104.8 minutes
#
# 🔄  Processing chunk 126/354 (rows 62500-62999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 63000)
#   📈  Rate: 18.2 rows/sec, ETA: 104.4 minutes
#
# 🔄  Processing chunk 127/354 (rows 63000-63499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 63500)
#   📈  Rate: 18.2 rows/sec, ETA: 104.0 minutes
#
# 🔄  Processing chunk 128/354 (rows 63500-63999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 64000)
#   📈  Rate: 18.2 rows/sec, ETA: 103.6 minutes
#
# 🔄  Processing chunk 129/354 (rows 64000-64499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 64500)
#   📈  Rate: 18.2 rows/sec, ETA: 103.2 minutes
#
# 🔄  Processing chunk 130/354 (rows 64500-64999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 65000)
#   📈  Rate: 18.2 rows/sec, ETA: 102.8 minutes
#
# 🔄  Processing chunk 131/354 (rows 65000-65499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 65500)
#   📈  Rate: 18.1 rows/sec, ETA: 102.4 minutes
#
# 🔄  Processing chunk 132/354 (rows 65500-65999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 66000)
#   📈  Rate: 18.1 rows/sec, ETA: 102.0 minutes
#
# 🔄  Processing chunk 133/354 (rows 66000-66499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 66500)
#   📈  Rate: 18.1 rows/sec, ETA: 101.5 minutes
#
# 🔄  Processing chunk 134/354 (rows 66500-66999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 67000)
#   📈  Rate: 18.1 rows/sec, ETA: 101.2 minutes
#
# 🔄  Processing chunk 135/354 (rows 67000-67499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 67500)
#   📈  Rate: 18.1 rows/sec, ETA: 100.8 minutes
#
# 🔄  Processing chunk 136/354 (rows 67500-67999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 68000)
#   📈  Rate: 18.1 rows/sec, ETA: 100.4 minutes
#
# 🔄  Processing chunk 137/354 (rows 68000-68499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 68500)
#   📈  Rate: 18.1 rows/sec, ETA: 99.9 minutes
#
# 🔄  Processing chunk 138/354 (rows 68500-68999)...
#   ⚠️  Translation attempt 1 failed: 'utf-8' codec can't encode characters in position 393-394: surrogates not allowed. Retrying in 2s...
#   ⚠️  Translation attempt 2 failed: 'utf-8' codec can't encode characters in position 393-394: surrogates not allowed. Retrying in 2s...
#   ⚠️  Translation attempt 3 failed: 'utf-8' codec can't encode characters in position 393-394: surrogates not allowed. Retrying in 2s...
#   ❌  Translation failed after 4 attempts: 'utf-8' codec can't encode characters in position 393-394: surrogates not allowed
#   ✅  Processed chunk: 500 success, 0 errors (total done: 69000)
#   📈  Rate: 18.0 rows/sec, ETA: 99.7 minutes
#
# 🔄  Processing chunk 139/354 (rows 69000-69499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 69500)
#   📈  Rate: 18.0 rows/sec, ETA: 99.3 minutes
#
# 🔄  Processing chunk 140/354 (rows 69500-69999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 70000)
#   📈  Rate: 18.0 rows/sec, ETA: 98.9 minutes
#
# 🔄  Processing chunk 141/354 (rows 70000-70499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 70500)
#   📈  Rate: 18.0 rows/sec, ETA: 98.5 minutes
#
# 🔄  Processing chunk 142/354 (rows 70500-70999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 71000)
#   📈  Rate: 18.0 rows/sec, ETA: 98.1 minutes
#
# 🔄  Processing chunk 143/354 (rows 71000-71499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 71500)
#   📈  Rate: 18.0 rows/sec, ETA: 97.8 minutes
#
# 🔄  Processing chunk 144/354 (rows 71500-71999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 72000)
#   📈  Rate: 18.0 rows/sec, ETA: 97.4 minutes
#
# 🔄  Processing chunk 145/354 (rows 72000-72499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 72500)
#   📈  Rate: 18.0 rows/sec, ETA: 97.0 minutes
#
# 🔄  Processing chunk 146/354 (rows 72500-72999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 73000)
#   📈  Rate: 17.9 rows/sec, ETA: 96.6 minutes
#
# 🔄  Processing chunk 147/354 (rows 73000-73499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 73500)
#   📈  Rate: 17.9 rows/sec, ETA: 96.2 minutes
#
# 🔄  Processing chunk 148/354 (rows 73500-73999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 74000)
#   📈  Rate: 17.9 rows/sec, ETA: 95.8 minutes
#
# 🔄  Processing chunk 149/354 (rows 74000-74499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 74500)
#   📈  Rate: 17.9 rows/sec, ETA: 95.4 minutes
#
# 🔄  Processing chunk 150/354 (rows 74500-74999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 75000)
#   📈  Rate: 17.9 rows/sec, ETA: 95.0 minutes
#
# 🔄  Processing chunk 151/354 (rows 75000-75499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 75500)
#   📈  Rate: 17.9 rows/sec, ETA: 94.6 minutes
#
# 🔄  Processing chunk 152/354 (rows 75500-75999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 76000)
#   📈  Rate: 17.9 rows/sec, ETA: 94.2 minutes
#
# 🔄  Processing chunk 153/354 (rows 76000-76499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 76500)
#   📈  Rate: 17.9 rows/sec, ETA: 93.7 minutes
#
# 🔄  Processing chunk 154/354 (rows 76500-76999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 77000)
#   📈  Rate: 17.9 rows/sec, ETA: 93.3 minutes
#
# 🔄  Processing chunk 155/354 (rows 77000-77499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 77500)
#   📈  Rate: 17.8 rows/sec, ETA: 92.9 minutes
#
# 🔄  Processing chunk 156/354 (rows 77500-77999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 78000)
#   📈  Rate: 17.8 rows/sec, ETA: 92.5 minutes
#
# 🔄  Processing chunk 157/354 (rows 78000-78499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 78500)
#   📈  Rate: 17.8 rows/sec, ETA: 92.1 minutes
#
# 🔄  Processing chunk 158/354 (rows 78500-78999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 79000)
#   📈  Rate: 17.8 rows/sec, ETA: 91.7 minutes
#
# 🔄  Processing chunk 159/354 (rows 79000-79499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 79500)
#   📈  Rate: 17.8 rows/sec, ETA: 91.3 minutes
#
# 🔄  Processing chunk 160/354 (rows 79500-79999)...
#   ⚠️  Translation attempt 1 failed: 'utf-8' codec can't encode characters in position 479-482: surrogates not allowed. Retrying in 2s...
#   ⚠️  Translation attempt 2 failed: 'utf-8' codec can't encode characters in position 479-482: surrogates not allowed. Retrying in 2s...
#   ⚠️  Translation attempt 3 failed: 'utf-8' codec can't encode characters in position 479-482: surrogates not allowed. Retrying in 2s...
#   ❌  Translation failed after 4 attempts: 'utf-8' codec can't encode characters in position 479-482: surrogates not allowed
#   ✅  Processed chunk: 500 success, 0 errors (total done: 80000)
#   📈  Rate: 17.8 rows/sec, ETA: 91.0 minutes
#
# 🔄  Processing chunk 161/354 (rows 80000-80499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 80500)
#   📈  Rate: 17.7 rows/sec, ETA: 90.6 minutes
#
# 🔄  Processing chunk 162/354 (rows 80500-80999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 81000)
#   📈  Rate: 17.7 rows/sec, ETA: 90.2 minutes
#
# 🔄  Processing chunk 163/354 (rows 81000-81499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 81500)
#   📈  Rate: 17.7 rows/sec, ETA: 89.8 minutes
#
# 🔄  Processing chunk 164/354 (rows 81500-81999)...
#   ⚠️  Translation attempt 1 failed: 'utf-8' codec can't encode characters in position 225-226: surrogates not allowed. Retrying in 2s...
#   ⚠️  Translation attempt 2 failed: 'utf-8' codec can't encode characters in position 225-226: surrogates not allowed. Retrying in 2s...
#   ⚠️  Translation attempt 3 failed: 'utf-8' codec can't encode characters in position 225-226: surrogates not allowed. Retrying in 2s...
#   ❌  Translation failed after 4 attempts: 'utf-8' codec can't encode characters in position 225-226: surrogates not allowed
#   ✅  Processed chunk: 500 success, 0 errors (total done: 82000)
#   📈  Rate: 17.7 rows/sec, ETA: 89.6 minutes
#
# 🔄  Processing chunk 165/354 (rows 82000-82499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 82500)
#   📈  Rate: 17.7 rows/sec, ETA: 89.1 minutes
#
# 🔄  Processing chunk 166/354 (rows 82500-82999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 83000)
#   📈  Rate: 17.7 rows/sec, ETA: 88.7 minutes
#
# 🔄  Processing chunk 167/354 (rows 83000-83499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 83500)
#   📈  Rate: 17.6 rows/sec, ETA: 88.3 minutes
#
# 🔄  Processing chunk 168/354 (rows 83500-83999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 84000)
#   📈  Rate: 17.6 rows/sec, ETA: 87.9 minutes
#
# 🔄  Processing chunk 169/354 (rows 84000-84499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 84500)
#   📈  Rate: 17.6 rows/sec, ETA: 87.5 minutes
#
# 🔄  Processing chunk 170/354 (rows 84500-84999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 85000)
#   📈  Rate: 17.6 rows/sec, ETA: 87.1 minutes
#
# 🔄  Processing chunk 171/354 (rows 85000-85499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 85500)
#   📈  Rate: 17.6 rows/sec, ETA: 86.7 minutes
#
# 🔄  Processing chunk 172/354 (rows 85500-85999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 86000)
#   📈  Rate: 17.6 rows/sec, ETA: 86.2 minutes
#
# 🔄  Processing chunk 173/354 (rows 86000-86499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 86500)
#   📈  Rate: 17.6 rows/sec, ETA: 85.8 minutes
#
# 🔄  Processing chunk 174/354 (rows 86500-86999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 87000)
#   📈  Rate: 17.6 rows/sec, ETA: 85.3 minutes
#
# 🔄  Processing chunk 175/354 (rows 87000-87499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 87500)
#   📈  Rate: 17.6 rows/sec, ETA: 84.9 minutes
#
# 🔄  Processing chunk 176/354 (rows 87500-87999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 88000)
#   📈  Rate: 17.6 rows/sec, ETA: 84.5 minutes
#
# 🔄  Processing chunk 177/354 (rows 88000-88499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 88500)
#   📈  Rate: 17.5 rows/sec, ETA: 84.0 minutes
#
# 🔄  Processing chunk 178/354 (rows 88500-88999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 89000)
#   📈  Rate: 17.5 rows/sec, ETA: 83.6 minutes
#
# 🔄  Processing chunk 179/354 (rows 89000-89499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 89500)
#   📈  Rate: 17.5 rows/sec, ETA: 83.3 minutes
#
# 🔄  Processing chunk 180/354 (rows 89500-89999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 90000)
#   📈  Rate: 17.5 rows/sec, ETA: 82.8 minutes
#
# 🔄  Processing chunk 181/354 (rows 90000-90499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 90500)
#   📈  Rate: 17.5 rows/sec, ETA: 82.4 minutes
#
# 🔄  Processing chunk 182/354 (rows 90500-90999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 91000)
#   📈  Rate: 17.5 rows/sec, ETA: 82.0 minutes
#
# 🔄  Processing chunk 183/354 (rows 91000-91499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 91500)
#   📈  Rate: 17.5 rows/sec, ETA: 81.6 minutes
#
# 🔄  Processing chunk 184/354 (rows 91500-91999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 92000)
#   📈  Rate: 17.5 rows/sec, ETA: 81.1 minutes
#
# 🔄  Processing chunk 185/354 (rows 92000-92499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 92500)
#   📈  Rate: 17.4 rows/sec, ETA: 80.7 minutes
#
# 🔄  Processing chunk 186/354 (rows 92500-92999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 93000)
#   📈  Rate: 17.4 rows/sec, ETA: 80.3 minutes
#
# 🔄  Processing chunk 187/354 (rows 93000-93499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 93500)
#   📈  Rate: 17.4 rows/sec, ETA: 79.9 minutes
#
# 🔄  Processing chunk 188/354 (rows 93500-93999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 94000)
#   📈  Rate: 17.4 rows/sec, ETA: 79.5 minutes
#
# 🔄  Processing chunk 189/354 (rows 94000-94499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 94500)
#   📈  Rate: 17.4 rows/sec, ETA: 79.0 minutes
#
# 🔄  Processing chunk 190/354 (rows 94500-94999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 95000)
#   📈  Rate: 17.4 rows/sec, ETA: 78.6 minutes
#
# 🔄  Processing chunk 191/354 (rows 95000-95499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 95500)
#   📈  Rate: 17.4 rows/sec, ETA: 78.2 minutes
#
# 🔄  Processing chunk 192/354 (rows 95500-95999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 96000)
#   📈  Rate: 17.4 rows/sec, ETA: 77.7 minutes
#
# 🔄  Processing chunk 193/354 (rows 96000-96499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 96500)
#   📈  Rate: 17.4 rows/sec, ETA: 77.2 minutes
#
# 🔄  Processing chunk 194/354 (rows 96500-96999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 97000)
#   📈  Rate: 17.4 rows/sec, ETA: 76.8 minutes
#
# 🔄  Processing chunk 195/354 (rows 97000-97499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 97500)
#   📈  Rate: 17.4 rows/sec, ETA: 76.4 minutes
#
# 🔄  Processing chunk 196/354 (rows 97500-97999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 98000)
#   📈  Rate: 17.3 rows/sec, ETA: 75.9 minutes
#
# 🔄  Processing chunk 197/354 (rows 98000-98499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 98500)
#   📈  Rate: 17.3 rows/sec, ETA: 75.5 minutes
#
# 🔄  Processing chunk 198/354 (rows 98500-98999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 99000)
#   📈  Rate: 17.3 rows/sec, ETA: 75.0 minutes
#
# 🔄  Processing chunk 199/354 (rows 99000-99499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 99500)
#   📈  Rate: 17.3 rows/sec, ETA: 74.6 minutes
#
# 🔄  Processing chunk 200/354 (rows 99500-99999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 100000)
#   📈  Rate: 17.3 rows/sec, ETA: 74.2 minutes
#
# 🔄  Processing chunk 201/354 (rows 100000-100499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 100500)
#   📈  Rate: 17.3 rows/sec, ETA: 73.8 minutes
#
# 🔄  Processing chunk 202/354 (rows 100500-100999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 101000)
#   📈  Rate: 17.3 rows/sec, ETA: 73.4 minutes
#
# 🔄  Processing chunk 203/354 (rows 101000-101499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 101500)
#   📈  Rate: 17.3 rows/sec, ETA: 72.9 minutes
#
# 🔄  Processing chunk 204/354 (rows 101500-101999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 102000)
#   📈  Rate: 17.2 rows/sec, ETA: 72.5 minutes
#
# 🔄  Processing chunk 205/354 (rows 102000-102499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 102500)
#   📈  Rate: 17.2 rows/sec, ETA: 72.0 minutes
#
# 🔄  Processing chunk 206/354 (rows 102500-102999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 103000)
#   📈  Rate: 17.2 rows/sec, ETA: 71.6 minutes
#
# 🔄  Processing chunk 207/354 (rows 103000-103499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 103500)
#   📈  Rate: 17.2 rows/sec, ETA: 71.1 minutes
#
# 🔄  Processing chunk 208/354 (rows 103500-103999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 104000)
#   📈  Rate: 17.2 rows/sec, ETA: 70.7 minutes
#
# 🔄  Processing chunk 209/354 (rows 104000-104499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 104500)
#   📈  Rate: 17.2 rows/sec, ETA: 70.2 minutes
#
# 🔄  Processing chunk 210/354 (rows 104500-104999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 105000)
#   📈  Rate: 17.2 rows/sec, ETA: 69.8 minutes
#
# 🔄  Processing chunk 211/354 (rows 105000-105499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 105500)
#   📈  Rate: 17.2 rows/sec, ETA: 69.3 minutes
#
# 🔄  Processing chunk 212/354 (rows 105500-105999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 106000)
#   📈  Rate: 17.2 rows/sec, ETA: 68.9 minutes
#
# 🔄  Processing chunk 213/354 (rows 106000-106499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 106500)
#   📈  Rate: 17.2 rows/sec, ETA: 68.4 minutes
#
# 🔄  Processing chunk 214/354 (rows 106500-106999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 107000)
#   📈  Rate: 17.2 rows/sec, ETA: 68.0 minutes
#
# 🔄  Processing chunk 215/354 (rows 107000-107499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 107500)
#   📈  Rate: 17.1 rows/sec, ETA: 67.6 minutes
#
# 🔄  Processing chunk 216/354 (rows 107500-107999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 108000)
#   📈  Rate: 17.1 rows/sec, ETA: 67.1 minutes
#
# 🔄  Processing chunk 217/354 (rows 108000-108499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 108500)
#   📈  Rate: 17.1 rows/sec, ETA: 66.7 minutes
#
# 🔄  Processing chunk 218/354 (rows 108500-108999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 109000)
#   📈  Rate: 17.1 rows/sec, ETA: 66.3 minutes
#
# 🔄  Processing chunk 219/354 (rows 109000-109499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 109500)
#   📈  Rate: 17.1 rows/sec, ETA: 65.8 minutes
#
# 🔄  Processing chunk 220/354 (rows 109500-109999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 110000)
#   📈  Rate: 17.1 rows/sec, ETA: 65.4 minutes
#
# 🔄  Processing chunk 221/354 (rows 110000-110499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 110500)
#   📈  Rate: 17.1 rows/sec, ETA: 64.9 minutes
#
# 🔄  Processing chunk 222/354 (rows 110500-110999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 111000)
#   📈  Rate: 17.1 rows/sec, ETA: 64.5 minutes
#
# 🔄  Processing chunk 223/354 (rows 111000-111499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 111500)
#   📈  Rate: 17.1 rows/sec, ETA: 64.0 minutes
#
# 🔄  Processing chunk 224/354 (rows 111500-111999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 112000)
#   📈  Rate: 17.0 rows/sec, ETA: 63.6 minutes
#
# 🔄  Processing chunk 225/354 (rows 112000-112499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 112500)
#   📈  Rate: 17.0 rows/sec, ETA: 63.1 minutes
#
# 🔄  Processing chunk 226/354 (rows 112500-112999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 113000)
#   📈  Rate: 17.0 rows/sec, ETA: 62.7 minutes
#
# 🔄  Processing chunk 227/354 (rows 113000-113499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 113500)
#   📈  Rate: 17.0 rows/sec, ETA: 62.2 minutes
#
# 🔄  Processing chunk 228/354 (rows 113500-113999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 114000)
#   📈  Rate: 17.0 rows/sec, ETA: 61.8 minutes
#
# 🔄  Processing chunk 229/354 (rows 114000-114499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 114500)
#   📈  Rate: 17.0 rows/sec, ETA: 61.3 minutes
#
# 🔄  Processing chunk 230/354 (rows 114500-114999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 115000)
#   📈  Rate: 17.0 rows/sec, ETA: 60.9 minutes
#
# 🔄  Processing chunk 231/354 (rows 115000-115499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 115500)
#   📈  Rate: 17.0 rows/sec, ETA: 60.4 minutes
#
# 🔄  Processing chunk 232/354 (rows 115500-115999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 116000)
#   📈  Rate: 17.0 rows/sec, ETA: 60.0 minutes
#
# 🔄  Processing chunk 233/354 (rows 116000-116499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 116500)
#   📈  Rate: 16.9 rows/sec, ETA: 59.5 minutes
#
# 🔄  Processing chunk 234/354 (rows 116500-116999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 117000)
#   📈  Rate: 16.9 rows/sec, ETA: 59.1 minutes
#
# 🔄  Processing chunk 235/354 (rows 117000-117499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 117500)
#   📈  Rate: 16.9 rows/sec, ETA: 58.6 minutes
#
# 🔄  Processing chunk 236/354 (rows 117500-117999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 118000)
#   📈  Rate: 16.9 rows/sec, ETA: 58.1 minutes
#
# 🔄  Processing chunk 237/354 (rows 118000-118499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 118500)
#   📈  Rate: 16.9 rows/sec, ETA: 57.7 minutes
#
# 🔄  Processing chunk 238/354 (rows 118500-118999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 119000)
#   📈  Rate: 16.9 rows/sec, ETA: 57.2 minutes
#
# 🔄  Processing chunk 239/354 (rows 119000-119499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 119500)
#   📈  Rate: 16.9 rows/sec, ETA: 56.7 minutes
#
# 🔄  Processing chunk 240/354 (rows 119500-119999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 120000)
#   📈  Rate: 16.9 rows/sec, ETA: 56.3 minutes
#
# 🔄  Processing chunk 241/354 (rows 120000-120499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 120500)
#   📈  Rate: 16.9 rows/sec, ETA: 55.8 minutes
#
# 🔄  Processing chunk 242/354 (rows 120500-120999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 121000)
#   📈  Rate: 16.9 rows/sec, ETA: 55.4 minutes
#
# 🔄  Processing chunk 243/354 (rows 121000-121499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 121500)
#   📈  Rate: 16.8 rows/sec, ETA: 54.9 minutes
#
# 🔄  Processing chunk 244/354 (rows 121500-121999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 122000)
#   📈  Rate: 16.8 rows/sec, ETA: 54.5 minutes
#
# 🔄  Processing chunk 245/354 (rows 122000-122499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 122500)
#   📈  Rate: 16.8 rows/sec, ETA: 54.0 minutes
#
# 🔄  Processing chunk 246/354 (rows 122500-122999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 123000)
#   📈  Rate: 16.8 rows/sec, ETA: 53.5 minutes
#
# 🔄  Processing chunk 247/354 (rows 123000-123499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 123500)
#   📈  Rate: 16.8 rows/sec, ETA: 53.0 minutes
#
# 🔄  Processing chunk 248/354 (rows 123500-123999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 124000)
#   📈  Rate: 16.8 rows/sec, ETA: 52.6 minutes
#
# 🔄  Processing chunk 249/354 (rows 124000-124499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 124500)
#   📈  Rate: 16.8 rows/sec, ETA: 52.1 minutes
#
# 🔄  Processing chunk 250/354 (rows 124500-124999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 125000)
#   📈  Rate: 16.8 rows/sec, ETA: 51.6 minutes
#
# 🔄  Processing chunk 251/354 (rows 125000-125499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 125500)
#   📈  Rate: 16.8 rows/sec, ETA: 51.2 minutes
#
# 🔄  Processing chunk 252/354 (rows 125500-125999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 126000)
#   📈  Rate: 16.8 rows/sec, ETA: 50.7 minutes
#
# 🔄  Processing chunk 253/354 (rows 126000-126499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 126500)
#   📈  Rate: 16.8 rows/sec, ETA: 50.2 minutes
#
# 🔄  Processing chunk 254/354 (rows 126500-126999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 127000)
#   📈  Rate: 16.7 rows/sec, ETA: 49.8 minutes
#
# 🔄  Processing chunk 255/354 (rows 127000-127499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 127500)
#   📈  Rate: 16.7 rows/sec, ETA: 49.3 minutes
#
# 🔄  Processing chunk 256/354 (rows 127500-127999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 128000)
#   📈  Rate: 16.7 rows/sec, ETA: 48.8 minutes
#
# 🔄  Processing chunk 257/354 (rows 128000-128499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 128500)
#   📈  Rate: 16.7 rows/sec, ETA: 48.3 minutes
#
# 🔄  Processing chunk 258/354 (rows 128500-128999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 129000)
#   📈  Rate: 16.7 rows/sec, ETA: 47.8 minutes
#
# 🔄  Processing chunk 259/354 (rows 129000-129499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 129500)
#   📈  Rate: 16.7 rows/sec, ETA: 47.4 minutes
#
# 🔄  Processing chunk 260/354 (rows 129500-129999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 130000)
#   📈  Rate: 16.7 rows/sec, ETA: 46.9 minutes
#
# 🔄  Processing chunk 261/354 (rows 130000-130499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 130500)
#   📈  Rate: 16.7 rows/sec, ETA: 46.4 minutes
#
# 🔄  Processing chunk 262/354 (rows 130500-130999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 131000)
#   📈  Rate: 16.7 rows/sec, ETA: 46.0 minutes
#
# 🔄  Processing chunk 263/354 (rows 131000-131499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 131500)
#   📈  Rate: 16.7 rows/sec, ETA: 45.5 minutes
#
# 🔄  Processing chunk 264/354 (rows 131500-131999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 132000)
#   📈  Rate: 16.7 rows/sec, ETA: 45.0 minutes
#
# 🔄  Processing chunk 265/354 (rows 132000-132499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 132500)
#   📈  Rate: 16.7 rows/sec, ETA: 44.5 minutes
#
# 🔄  Processing chunk 266/354 (rows 132500-132999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 133000)
#   📈  Rate: 16.6 rows/sec, ETA: 44.1 minutes
#
# 🔄  Processing chunk 267/354 (rows 133000-133499)...
#   ⚠️  Translation attempt 1 failed: 'utf-8' codec can't encode characters in position 77-78: surrogates not allowed. Retrying in 2s...
#   ⚠️  Translation attempt 2 failed: 'utf-8' codec can't encode characters in position 77-78: surrogates not allowed. Retrying in 2s...
#   ⚠️  Translation attempt 3 failed: 'utf-8' codec can't encode characters in position 77-78: surrogates not allowed. Retrying in 2s...
#   ❌  Translation failed after 4 attempts: 'utf-8' codec can't encode characters in position 77-78: surrogates not allowed
#   ✅  Processed chunk: 500 success, 0 errors (total done: 133500)
#   📈  Rate: 16.6 rows/sec, ETA: 43.6 minutes
#
# 🔄  Processing chunk 268/354 (rows 133500-133999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 134000)
#   📈  Rate: 16.6 rows/sec, ETA: 43.2 minutes
#
# 🔄  Processing chunk 269/354 (rows 134000-134499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 134500)
#   📈  Rate: 16.6 rows/sec, ETA: 42.7 minutes
#
# 🔄  Processing chunk 270/354 (rows 134500-134999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 135000)
#   📈  Rate: 16.6 rows/sec, ETA: 42.2 minutes
#
# 🔄  Processing chunk 271/354 (rows 135000-135499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 135500)
#   📈  Rate: 16.6 rows/sec, ETA: 41.7 minutes
#
# 🔄  Processing chunk 272/354 (rows 135500-135999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 136000)
#   📈  Rate: 16.6 rows/sec, ETA: 41.3 minutes
#
# 🔄  Processing chunk 273/354 (rows 136000-136499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 136500)
#   📈  Rate: 16.6 rows/sec, ETA: 40.8 minutes
#
# 🔄  Processing chunk 274/354 (rows 136500-136999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 137000)
#   📈  Rate: 16.6 rows/sec, ETA: 40.3 minutes
#
# 🔄  Processing chunk 275/354 (rows 137000-137499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 137500)
#   📈  Rate: 16.5 rows/sec, ETA: 39.8 minutes
#
# 🔄  Processing chunk 276/354 (rows 137500-137999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 138000)
#   📈  Rate: 16.5 rows/sec, ETA: 39.3 minutes
#
# 🔄  Processing chunk 277/354 (rows 138000-138499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 138500)
#   📈  Rate: 16.5 rows/sec, ETA: 38.8 minutes
#
# 🔄  Processing chunk 278/354 (rows 138500-138999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 139000)
#   📈  Rate: 16.5 rows/sec, ETA: 38.4 minutes
#
# 🔄  Processing chunk 279/354 (rows 139000-139499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 139500)
#   📈  Rate: 16.5 rows/sec, ETA: 37.9 minutes
#
# 🔄  Processing chunk 280/354 (rows 139500-139999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 140000)
#   📈  Rate: 16.5 rows/sec, ETA: 37.4 minutes
#
# 🔄  Processing chunk 281/354 (rows 140000-140499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 140500)
#   📈  Rate: 16.5 rows/sec, ETA: 36.9 minutes
#
# 🔄  Processing chunk 282/354 (rows 140500-140999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 141000)
#   📈  Rate: 16.5 rows/sec, ETA: 36.4 minutes
#
# 🔄  Processing chunk 283/354 (rows 141000-141499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 141500)
#   📈  Rate: 16.5 rows/sec, ETA: 35.9 minutes
#
# 🔄  Processing chunk 284/354 (rows 141500-141999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 142000)
#   📈  Rate: 16.5 rows/sec, ETA: 35.4 minutes
#
# 🔄  Processing chunk 285/354 (rows 142000-142499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 142500)
#   📈  Rate: 16.5 rows/sec, ETA: 34.9 minutes
#
# 🔄  Processing chunk 286/354 (rows 142500-142999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 143000)
#   📈  Rate: 16.4 rows/sec, ETA: 34.5 minutes
#
# 🔄  Processing chunk 287/354 (rows 143000-143499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 143500)
#   📈  Rate: 16.4 rows/sec, ETA: 34.0 minutes
#
# 🔄  Processing chunk 288/354 (rows 143500-143999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 144000)
#   📈  Rate: 16.4 rows/sec, ETA: 33.5 minutes
#
# 🔄  Processing chunk 289/354 (rows 144000-144499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 144500)
#   📈  Rate: 16.4 rows/sec, ETA: 33.0 minutes
#
# 🔄  Processing chunk 290/354 (rows 144500-144999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 145000)
#   📈  Rate: 16.4 rows/sec, ETA: 32.5 minutes
#
# 🔄  Processing chunk 291/354 (rows 145000-145499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 145500)
#   📈  Rate: 16.4 rows/sec, ETA: 32.0 minutes
#
# 🔄  Processing chunk 292/354 (rows 145500-145999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 146000)
#   📈  Rate: 16.4 rows/sec, ETA: 31.5 minutes
#
# 🔄  Processing chunk 293/354 (rows 146000-146499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 146500)
#   📈  Rate: 16.4 rows/sec, ETA: 31.0 minutes
#
# 🔄  Processing chunk 294/354 (rows 146500-146999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 147000)
#   📈  Rate: 16.4 rows/sec, ETA: 30.5 minutes
#
# 🔄  Processing chunk 295/354 (rows 147000-147499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 147500)
#   📈  Rate: 16.4 rows/sec, ETA: 30.1 minutes
#
# 🔄  Processing chunk 296/354 (rows 147500-147999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 148000)
#   📈  Rate: 16.4 rows/sec, ETA: 29.6 minutes
#
# 🔄  Processing chunk 297/354 (rows 148000-148499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 148500)
#   📈  Rate: 16.3 rows/sec, ETA: 29.1 minutes
#
# 🔄  Processing chunk 298/354 (rows 148500-148999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 149000)
#   📈  Rate: 16.3 rows/sec, ETA: 28.6 minutes
#
# 🔄  Processing chunk 299/354 (rows 149000-149499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 149500)
#   📈  Rate: 16.3 rows/sec, ETA: 28.1 minutes
#
# 🔄  Processing chunk 300/354 (rows 149500-149999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 150000)
#   📈  Rate: 16.3 rows/sec, ETA: 27.6 minutes
#
# 🔄  Processing chunk 301/354 (rows 150000-150499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 150500)
#   📈  Rate: 16.3 rows/sec, ETA: 27.1 minutes
#
# 🔄  Processing chunk 302/354 (rows 150500-150999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 151000)
#   📈  Rate: 16.3 rows/sec, ETA: 26.6 minutes
#
# 🔄  Processing chunk 303/354 (rows 151000-151499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 151500)
#   📈  Rate: 16.3 rows/sec, ETA: 26.1 minutes
#
# 🔄  Processing chunk 304/354 (rows 151500-151999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 152000)
#   📈  Rate: 16.3 rows/sec, ETA: 25.6 minutes
#
# 🔄  Processing chunk 305/354 (rows 152000-152499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 152500)
#   📈  Rate: 16.3 rows/sec, ETA: 25.1 minutes
#
# 🔄  Processing chunk 306/354 (rows 152500-152999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 153000)
#   📈  Rate: 16.3 rows/sec, ETA: 24.6 minutes
#
# 🔄  Processing chunk 307/354 (rows 153000-153499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 153500)
#   📈  Rate: 16.3 rows/sec, ETA: 24.1 minutes
#
# 🔄  Processing chunk 308/354 (rows 153500-153999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 154000)
#   📈  Rate: 16.3 rows/sec, ETA: 23.6 minutes
#
# 🔄  Processing chunk 309/354 (rows 154000-154499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 154500)
#   📈  Rate: 16.2 rows/sec, ETA: 23.1 minutes
#
# 🔄  Processing chunk 310/354 (rows 154500-154999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 155000)
#   📈  Rate: 16.2 rows/sec, ETA: 22.6 minutes
#
# 🔄  Processing chunk 311/354 (rows 155000-155499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 155500)
#   📈  Rate: 16.2 rows/sec, ETA: 22.1 minutes
#
# 🔄  Processing chunk 312/354 (rows 155500-155999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 156000)
#   📈  Rate: 16.2 rows/sec, ETA: 21.6 minutes
#
# 🔄  Processing chunk 313/354 (rows 156000-156499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 156500)
#   📈  Rate: 16.2 rows/sec, ETA: 21.1 minutes
#
# 🔄  Processing chunk 314/354 (rows 156500-156999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 157000)
#   📈  Rate: 16.2 rows/sec, ETA: 20.6 minutes
#
# 🔄  Processing chunk 315/354 (rows 157000-157499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 157500)
#   📈  Rate: 16.2 rows/sec, ETA: 20.1 minutes
#
# 🔄  Processing chunk 316/354 (rows 157500-157999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 158000)
#   📈  Rate: 16.2 rows/sec, ETA: 19.6 minutes
#
# 🔄  Processing chunk 317/354 (rows 158000-158499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 158500)
#   📈  Rate: 16.2 rows/sec, ETA: 19.1 minutes
#
# 🔄  Processing chunk 318/354 (rows 158500-158999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 159000)
#   📈  Rate: 16.2 rows/sec, ETA: 18.6 minutes
#
# 🔄  Processing chunk 319/354 (rows 159000-159499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 159500)
#   📈  Rate: 16.2 rows/sec, ETA: 18.1 minutes
#
# 🔄  Processing chunk 320/354 (rows 159500-159999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 160000)
#   📈  Rate: 16.1 rows/sec, ETA: 17.6 minutes
#
# 🔄  Processing chunk 321/354 (rows 160000-160499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 160500)
#   📈  Rate: 16.1 rows/sec, ETA: 17.0 minutes
#
# 🔄  Processing chunk 322/354 (rows 160500-160999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 161000)
#   📈  Rate: 16.1 rows/sec, ETA: 16.5 minutes
#
# 🔄  Processing chunk 323/354 (rows 161000-161499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 161500)
#   📈  Rate: 16.1 rows/sec, ETA: 16.0 minutes
#
# 🔄  Processing chunk 324/354 (rows 161500-161999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 162000)
#   📈  Rate: 16.1 rows/sec, ETA: 15.5 minutes
#
# 🔄  Processing chunk 325/354 (rows 162000-162499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 162500)
#   📈  Rate: 16.1 rows/sec, ETA: 15.0 minutes
#
# 🔄  Processing chunk 326/354 (rows 162500-162999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 163000)
#   📈  Rate: 16.1 rows/sec, ETA: 14.5 minutes
#
# 🔄  Processing chunk 327/354 (rows 163000-163499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 163500)
#   📈  Rate: 16.1 rows/sec, ETA: 14.0 minutes
#
# 🔄  Processing chunk 328/354 (rows 163500-163999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 164000)
#   📈  Rate: 16.1 rows/sec, ETA: 13.5 minutes
#
# 🔄  Processing chunk 329/354 (rows 164000-164499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 164500)
#   📈  Rate: 16.1 rows/sec, ETA: 13.0 minutes
#
# 🔄  Processing chunk 330/354 (rows 164500-164999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 165000)
#   📈  Rate: 16.1 rows/sec, ETA: 12.5 minutes
#
# 🔄  Processing chunk 331/354 (rows 165000-165499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 165500)
#   📈  Rate: 16.0 rows/sec, ETA: 11.9 minutes
#
# 🔄  Processing chunk 332/354 (rows 165500-165999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 166000)
#   📈  Rate: 16.0 rows/sec, ETA: 11.4 minutes
#
# 🔄  Processing chunk 333/354 (rows 166000-166499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 166500)
#   📈  Rate: 16.0 rows/sec, ETA: 10.9 minutes
#
# 🔄  Processing chunk 334/354 (rows 166500-166999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 167000)
#   📈  Rate: 16.0 rows/sec, ETA: 10.4 minutes
#
# 🔄  Processing chunk 335/354 (rows 167000-167499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 167500)
#   📈  Rate: 16.0 rows/sec, ETA: 9.9 minutes
#
# 🔄  Processing chunk 336/354 (rows 167500-167999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 168000)
#   📈  Rate: 16.0 rows/sec, ETA: 9.4 minutes
#
# 🔄  Processing chunk 337/354 (rows 168000-168499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 168500)
#   📈  Rate: 16.0 rows/sec, ETA: 8.9 minutes
#
# 🔄  Processing chunk 338/354 (rows 168500-168999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 169000)
#   📈  Rate: 16.0 rows/sec, ETA: 8.3 minutes
#
# 🔄  Processing chunk 339/354 (rows 169000-169499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 169500)
#   📈  Rate: 16.0 rows/sec, ETA: 7.8 minutes
#
# 🔄  Processing chunk 340/354 (rows 169500-169999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 170000)
#   📈  Rate: 16.0 rows/sec, ETA: 7.3 minutes
#
# 🔄  Processing chunk 341/354 (rows 170000-170499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 170500)
#   📈  Rate: 16.0 rows/sec, ETA: 6.8 minutes
#
# 🔄  Processing chunk 342/354 (rows 170500-170999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 171000)
#   📈  Rate: 15.9 rows/sec, ETA: 6.3 minutes
#
# 🔄  Processing chunk 343/354 (rows 171000-171499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 171500)
#   📈  Rate: 15.9 rows/sec, ETA: 5.8 minutes
#
# 🔄  Processing chunk 344/354 (rows 171500-171999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 172000)
#   📈  Rate: 15.9 rows/sec, ETA: 5.2 minutes
#
# 🔄  Processing chunk 345/354 (rows 172000-172499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 172500)
#   📈  Rate: 15.9 rows/sec, ETA: 4.7 minutes
#
# 🔄  Processing chunk 346/354 (rows 172500-172999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 173000)
#   📈  Rate: 15.9 rows/sec, ETA: 4.2 minutes
#
# 🔄  Processing chunk 347/354 (rows 173000-173499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 173500)
#   📈  Rate: 15.9 rows/sec, ETA: 3.7 minutes
#
# 🔄  Processing chunk 348/354 (rows 173500-173999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 174000)
#   📈  Rate: 15.9 rows/sec, ETA: 3.1 minutes
#
# 🔄  Processing chunk 349/354 (rows 174000-174499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 174500)
#   📈  Rate: 15.9 rows/sec, ETA: 2.6 minutes
#
# 🔄  Processing chunk 350/354 (rows 174500-174999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 175000)
#   📈  Rate: 15.9 rows/sec, ETA: 2.1 minutes
#
# 🔄  Processing chunk 351/354 (rows 175000-175499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 175500)
#   📈  Rate: 15.9 rows/sec, ETA: 1.6 minutes
#
# 🔄  Processing chunk 352/354 (rows 175500-175999)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 176000)
#   📈  Rate: 15.9 rows/sec, ETA: 1.0 minutes
#
# 🔄  Processing chunk 353/354 (rows 176000-176499)...
#   ✅  Processed chunk: 500 success, 0 errors (total done: 176500)
#   📈  Rate: 15.9 rows/sec, ETA: 0.5 minutes
#
# 🔄  Processing chunk 354/354 (rows 176500-176998)...
#   ✅  Processed chunk: 499 success, 0 errors (total done: 176999)
#   📈  Rate: 15.8 rows/sec, ETA: 0.0 minutes
#
# ✅  Translation complete!
# 📊  Total processed: 176999
# ❌  Errors: 0
# 💾  Output saved to: /content/drive/MyDrive/Collab/Boafo/code-dataset-output_twi.csv

# %% [markdown]
# # CLEAN LLM DATA

# %%
import pandas as pd
import re

# === Step 1: Load your CSV ===
input_file = "/content/drive/MyDrive/Collab/Boafo/code-dataset-output_twi.csv"
output_file = "/content/drive/MyDrive/Collab/Boafo/code-dataset-output_twi_cleaned.csv"
df = pd.read_csv(input_file)

# === Step 2: Remove the first column ===
df = df.iloc[:, 1:]

# === Step 3: Rename conversations_twi to conversations ===
df = df.rename(columns={"conversations_twi": "conversations"})

# === Step 6: Save updated CSV ===
df.to_csv(output_file, index=False, encoding='utf-8')
print(f"✅ Cleaned CSV saved to {output_file}")
print(f"📊 Total rows: {len(df)}")
# Out:
# ✅ Cleaned CSV saved to /content/drive/MyDrive/Collab/Boafo/code-dataset-output_twi_cleaned.csv
# 📊 Total rows: 176999

# %% [markdown]
# # RESTORE PLACEHOLDERS

# %%
#!/usr/bin/env python3
"""
restore.py – restores original text from [N*@@] placeholders
"""
import csv
import re
from pathlib import Path

PLACEHOLDER_CSV = Path("/content/drive/MyDrive/Collab/Boafo/code-dataset-output_twi_cleaned.csv")
MAPPING_CSV     = Path("/content/drive/MyDrive/Collab/Boafo/mapping.csv")
RESTORED_CSV    = Path("/content/drive/MyDrive/Collab/Boafo/code-dataset-output_twi-final.csv")

def main():
    # 1. Build mapping {id -> original_text}
    mapping = {}
    with MAPPING_CSV.open(newline='', encoding='utf-8') as f:
        for row in csv.DictReader(f):
            # Convert id to integer for numeric lookup
            mapping[int(row['id'])] = row['original_text']

    # 2. Regex pattern that captures placeholders with format [number*@...@...]
    #    Matches square brackets containing digits, followed by *, followed by @ symbols
    placeholder_pat = re.compile(r'\[(\d+)\*@+\]')

    def expand(match):
        num = int(match.group(1))  # Extract and convert the number to integer
        return mapping.get(num, match.group(0))  # Replace if found, else keep

    # 3. Stream and process large CSV
    with PLACEHOLDER_CSV.open(newline='', encoding='utf-8') as infile, \
         RESTORED_CSV.open('w', newline='', encoding='utf-8') as outfile:

        reader = csv.DictReader(infile)
        writer = csv.DictWriter(outfile, fieldnames=reader.fieldnames)
        writer.writeheader()

        for n, row in enumerate(reader, 1):
            if 'conversations' in row and row['conversations']:
                row['conversations'] = placeholder_pat.sub(expand, row['conversations'])
            writer.writerow(row)

            if n % 10_000 == 0:
                print(f"  {n:,} rows restored", end='\r')

        print(f"\n✅  {n:,} rows restored -> {RESTORED_CSV}")

if __name__ == '__main__':
    main()
# Out:
# ✅  176,999 rows restored -> /content/drive/MyDrive/Collab/Boafo/code-dataset-output_twi-final.csv

# %% [markdown]
# # PUSH TO HF

# %%
import pandas as pd
from datasets import Dataset, DatasetDict
import os
from huggingface_hub import login
import json
import ast
import re

def clean_text(text):
    """Remove invalid Unicode surrogate characters"""
    if isinstance(text, str):
        # Remove surrogate characters (U+D800 to U+DFFF)
        return text.encode('utf-8', errors='ignore').decode('utf-8', errors='ignore')
    return text

def clean_conversation(conv):
    """Clean all text in a conversation"""
    if not isinstance(conv, list):
        return conv

    cleaned = []
    for turn in conv:
        if isinstance(turn, dict):
            cleaned_turn = {}
            for key, value in turn.items():
                cleaned_turn[key] = clean_text(value)
            cleaned.append(cleaned_turn)
        else:
            cleaned.append(turn)

    return cleaned

def parse_conversation_string(conv_str):
    """
    Parse a conversation string that may contain Python list syntax
    """
    # Handle NaN or None
    if pd.isna(conv_str) or conv_str is None:
        return None

    # Convert to string and clean
    conv_str = str(conv_str).strip()

    if not conv_str or conv_str == 'nan':
        return None

    try:
        # Try ast.literal_eval (works for Python list syntax)
        result = ast.literal_eval(conv_str)
        if isinstance(result, list) and len(result) > 0:
            # Clean the parsed result
            return clean_conversation(result)
    except:
        pass

    try:
        # Try JSON parsing
        result = json.loads(conv_str)
        if isinstance(result, list) and len(result) > 0:
            return clean_conversation(result)
    except:
        pass

    return None

def upload_dataset_to_hf(csv_file_path, repo_id, token):
    """
    Upload a single-column CSV dataset to Hugging Face Hub
    """

    # Login to Hugging Face
    login(token=token)

    print("Reading CSV file (single column format)...")

    # Read with specific settings for single column with embedded newlines
    df = pd.read_csv(
        csv_file_path,
        header=0,
        quoting=1,  # QUOTE_ALL
        doublequote=True,
        escapechar=None,
        encoding='utf-8',
        on_bad_lines='skip',
        engine='python'  # Python engine handles complex cases better
    )

    print(f"Loaded dataframe shape: {df.shape}")
    print(f"Columns: {list(df.columns)}")

    # Check if we have the conversations column
    if 'conversations' not in df.columns:
        print(f"❌ Expected 'conversations' column but found: {list(df.columns)}")
        return

    print(f"\nOriginal rows: {len(df)}")

    # Show sample of raw data
    print("\n📝 Sample raw data (first 3 rows):")
    for i in range(min(3, len(df))):
        raw = str(df['conversations'].iloc[i])
        print(f"  Row {i}: {raw[:150]}...")

    # Parse the conversations column
    print("\n🔄 Parsing conversations...")
    df['conversations'] = df['conversations'].apply(parse_conversation_string)

    # Remove None values
    valid_mask = df['conversations'].notna()
    failed_count = (~valid_mask).sum()

    print(f"\n📊 Parsing results:")
    print(f"  Total rows: {len(df)}")
    print(f"  Failed: {failed_count}")
    print(f"  Success: {valid_mask.sum()}")

    # Filter to valid rows only
    df = df[valid_mask].copy()

    # Additional validation
    df = df[df['conversations'].apply(lambda x: isinstance(x, list) and len(x) > 0)]

    print(f"  Final valid rows: {len(df)}")

    if len(df) == 0:
        print("\n❌ ERROR: No valid conversations could be parsed!")
        return

    # Show parsed sample
    print(f"\n✅ Sample parsed data:")
    sample = df['conversations'].iloc[0]
    print(f"  Type: {type(sample)}")
    print(f"  Number of turns: {len(sample)}")
    print(f"  First turn:")
    print(json.dumps(sample[0], ensure_ascii=False, indent=4)[:400])

    # Reset index
    df = df.reset_index(drop=True)

    # Convert to Hugging Face dataset
    print("\n📦 Converting to Hugging Face dataset...")

    # Create a clean dataset dict for conversion
    clean_data = {'conversations': df['conversations'].tolist()}

    # Convert using from_dict instead of from_pandas to avoid encoding issues
    dataset = Dataset.from_dict(clean_data)

    # Create dataset dictionary
    dataset_dict = DatasetDict({
        "train": dataset
    })

    # Push to Hub
    print(f"\n☁️  Uploading to {repo_id}...")
    try:
        dataset_dict.push_to_hub(
            repo_id,
            token=token,
            commit_message="Upload Code-170k-ga - Ga language coding conversations dataset",
            private=False
        )

        print("\n✅ SUCCESS! Dataset uploaded!")
        print(f"\n📊 Dataset Info:")
        print(f"   🔗 URL: https://huggingface.co/datasets/{repo_id}")
        print(f"   📝 Samples: {len(dataset):,}")
        print(f"   📋 Columns: {', '.join(dataset.column_names)}")

    except Exception as e:
        print(f"\n❌ Upload failed!")
        print(f"Error: {e}")

        # Try to save locally as backup
        try:
            backup_path = "/content/dataset_backup.jsonl"
            print(f"\n💾 Saving backup to {backup_path}...")
            with open(backup_path, 'w', encoding='utf-8') as f:
                for conv in clean_data['conversations']:
                    f.write(json.dumps({'conversations': conv}, ensure_ascii=False) + '\n')
            print(f"✅ Backup saved successfully!")
        except Exception as backup_error:
            print(f"❌ Backup also failed: {backup_error}")

def main():
    CSV_FILE_PATH = "/content/drive/MyDrive/Collab/Boafo/code-dataset-output_twi-final.csv"
    REPO_ID = f"{USERNAME}/{REPO_NAME}"

    if not os.path.exists(CSV_FILE_PATH):
        print(f"❌ File not found: {CSV_FILE_PATH}")
        return

    print(f"✓ Found file: {CSV_FILE_PATH}")
    print(f"✓ Target repo: {REPO_ID}\n")
    print("="*60)

    upload_dataset_to_hf(CSV_FILE_PATH, REPO_ID, HF_TOKEN)

if __name__ == "__main__":
    # ⚠️ WARNING: REGENERATE YOUR TOKEN - it's been exposed!
    HF_TOKEN = "INSERTT-HUGGING-FACE-TOKEN-HERE"
    USERNAME = "INSERT-HUGGING-FACE-USERNAME-HERE"
    REPO_NAME = "REPLACE*WITH*NAME*OF*MODEL"

    main()
# Out:
# ✓ Found file: /content/drive/MyDrive/Collab/Boafo/code-dataset-output_twi-final.csv
# ✓ Target repo: michsethowusu/Code-170k-ga
#
# ============================================================
# Reading CSV file (single column format)...
# Loaded dataframe shape: (176999, 1)
# Columns: ['conversations']
#
# Original rows: 176999
#
# 📝 Sample raw data (first 3 rows):
#   Row 0: [{'from': 'human', 'value': 'Te abaafee tɛŋŋ afee algorithm ko koni ekɛtsake wiemɔi ni yɔɔ wiemɔ kuku mli lɛ?'}, {'from': 'gpt', 'value': 'Gbɛ kome ni...
#   Row 1: [{'from': 'human', 'value': 'Ani mɔ ko baanyɛ aye abua mi ni mayɔse programming wiemɔ ni akɛtsuɔ nii yɛ code snippet nɛɛ mli?\n\nKod Snippet:\n```\nde...
#   Row 2: [{'from': 'human', 'value': 'Ani abaanyɛ akɛ shishinumɔ ni aŋmala ashwie shi lɛ atsu nii ni akɛfee wiemɔi ashishitsɔɔmɔ wolo yɛ Python mli? Akɛ nɔkwɛm...
#
# 🔄 Parsing conversations...
#
# 📊 Parsing results:
#   Total rows: 176999
#   Failed: 46282
#   Success: 130717
#   Final valid rows: 130717
#
# ✅ Sample parsed data:
#   Type: <class 'list'>
#   Number of turns: 2
#   First turn:
# {
#     "from": "human",
#     "value": "Te abaafee tɛŋŋ afee algorithm ko koni ekɛtsake wiemɔi ni yɔɔ wiemɔ kuku mli lɛ?"
# }
#
# 📦 Converting to Hugging Face dataset...
#
# ☁️  Uploading to michsethowusu/Code-170k-ga...
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ? shards/s]
# Creating parquet from Arrow format:   0%|          | 0/131 [00:00<?, ?ba/s]
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#                               :   2%|1         | 2.10MB /  112MB
# ✅ SUCCESS! Dataset uploaded!
#
# 📊 Dataset Info:
#    🔗 URL: https://huggingface.co/datasets/michsethowusu/Code-170k-ga
#    📝 Samples: 130,717
#    📋 Columns: conversations
